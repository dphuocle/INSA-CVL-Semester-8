# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# chargement des donnees 
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# taille de l'image
M = 32
N = 32
channel = 3
nombre_train = train_images.shape[0]
nombre_test = test_images.shape[0]
print(nombre_train)
print(nombre_test)
# Out:
# 50000
# 10000

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
# Normalisation
train_images, test_images = train_images / 255.0, test_images / 255.0  

# Re-dimension
trainX = train_images.reshape((nombre_train, M, N, channel))
testX = test_images.reshape((nombre_test, M, N, channel))

trainX = trainX.reshape(nombre_train, channel*M*N)
testX = testX.reshape(nombre_test, channel*M*N)

# %%
# L'architecture
model = models.Sequential()
# Couche d'entree
model.add(layers.Dense(64, activation='relu', input_dim=M*N*channel))
# Couche cachee suivante
model.add(layers.Dense(256, activation='relu', input_dim=64))
# Couche cachee suivante
model.add(layers.Dense(64, activation='relu', input_dim=256))
# Couche de sortie
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                196672
#
#  dense_1 (Dense)             (None, 256)               16640
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 230410 (900.04 KB)
# Trainable params: 230410 (900.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.8)
model.compile(optimizer=opt, loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print("[INFO] training model...")
history = model.fit(trainX, train_labels, validation_data=(testX, test_labels), batch_size=64, epochs=30)
# Out:
# [INFO] training model...
# Epoch 1/30
# C:\Users\Phuoc Le\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 782/782 [==============================] - 4s 4ms/step - loss: 1.8811 - accuracy: 0.3157 - val_loss: 1.7394 - val_accuracy: 0.3702
# Epoch 2/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.6851 - accuracy: 0.3961 - val_loss: 1.6202 - val_accuracy: 0.4192
# Epoch 3/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6025 - accuracy: 0.4269 - val_loss: 1.6654 - val_accuracy: 0.4005
# Epoch 4/30
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5497 - accuracy: 0.4457 - val_loss: 1.5405 - val_accuracy: 0.4450
# Epoch 5/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.5103 - accuracy: 0.4614 - val_loss: 1.5356 - val_accuracy: 0.4485
# Epoch 6/30
# 782/782 [==============================] - 4s 4ms/step - loss: 1.4699 - accuracy: 0.4748 - val_loss: 1.5032 - val_accuracy: 0.4731
# Epoch 7/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.4418 - accuracy: 0.4852 - val_loss: 1.4857 - val_accuracy: 0.4628
# Epoch 8/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.4125 - accuracy: 0.4959 - val_loss: 1.4630 - val_accuracy: 0.4794
# Epoch 9/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.3937 - accuracy: 0.5010 - val_loss: 1.4788 - val_accuracy: 0.4712
# Epoch 10/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.3693 - accuracy: 0.5099 - val_loss: 1.4343 - val_accuracy: 0.4847
# Epoch 11/30
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3507 - accuracy: 0.5182 - val_loss: 1.4945 - val_accuracy: 0.4682
# Epoch 12/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.3285 - accuracy: 0.5240 - val_loss: 1.4082 - val_accuracy: 0.5003
# Epoch 13/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.3139 - accuracy: 0.5303 - val_loss: 1.4033 - val_accuracy: 0.4997
# Epoch 14/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.2974 - accuracy: 0.5355 - val_loss: 1.4954 - val_accuracy: 0.4624
# Epoch 15/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.2823 - accuracy: 0.5431 - val_loss: 1.4147 - val_accuracy: 0.4986
# Epoch 16/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.2635 - accuracy: 0.5486 - val_loss: 1.4238 - val_accuracy: 0.5022
# Epoch 17/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.2487 - accuracy: 0.5531 - val_loss: 1.4011 - val_accuracy: 0.5031
# Epoch 18/30
# 782/782 [==============================] - 2s 3ms/step - loss: 1.2397 - accuracy: 0.5542 - val_loss: 1.4328 - val_accuracy: 0.4970
# Epoch 19/30
# 782/782 [==============================] - 3s 4ms/step - loss: 1.2215 - accuracy: 0.5639 - val_loss: 1.4981 - val_accuracy: 0.4677
# Epoch 20/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.2114 - accuracy: 0.5661 - val_loss: 1.4401 - val_accuracy: 0.5009
# Epoch 21/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1932 - accuracy: 0.5749 - val_loss: 1.3986 - val_accuracy: 0.5064
# Epoch 22/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1840 - accuracy: 0.5753 - val_loss: 1.5140 - val_accuracy: 0.4733
# Epoch 23/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1735 - accuracy: 0.5798 - val_loss: 1.4015 - val_accuracy: 0.5045
# Epoch 24/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1603 - accuracy: 0.5841 - val_loss: 1.4101 - val_accuracy: 0.5125
# Epoch 25/30
# 782/782 [==============================] - 2s 3ms/step - loss: 1.1537 - accuracy: 0.5871 - val_loss: 1.3977 - val_accuracy: 0.5168
# Epoch 26/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1372 - accuracy: 0.5932 - val_loss: 1.4505 - val_accuracy: 0.5088
# Epoch 27/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1283 - accuracy: 0.5939 - val_loss: 1.4375 - val_accuracy: 0.4925
# Epoch 28/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1198 - accuracy: 0.5985 - val_loss: 1.4684 - val_accuracy: 0.5031
# Epoch 29/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.1054 - accuracy: 0.6026 - val_loss: 1.4093 - val_accuracy: 0.5115
# Epoch 30/30
# 782/782 [==============================] - 3s 3ms/step - loss: 1.0931 - accuracy: 0.6073 - val_loss: 1.4018 - val_accuracy: 0.5218

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(loc='lower right')

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
test_loss, test_acc = model.evaluate(testX, test_labels, verbose=2)
# Out:
# 313/313 - 0s - loss: 1.4018 - accuracy: 0.5218 - 410ms/epoch - 1ms/step

# %%
test_labels
# Out:
# array([[3],
#        [8],
#        [8],
#        ...,
#        [5],
#        [1],
#        [7]], dtype=uint8)
