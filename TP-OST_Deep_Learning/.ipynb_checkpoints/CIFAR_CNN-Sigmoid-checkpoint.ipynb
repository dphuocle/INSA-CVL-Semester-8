# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
# chargement des donnees 
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# taille de l'image
M = 32
N = 32
channel = 3
nombre_train = train_images.shape[0]
nombre_test = test_images.shape[0]
print(nombre_train)
print(nombre_test)
# Out:
# 50000
# 10000

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
# Normalisation
train_images, test_images = train_images / 255.0, test_images / 255.0  

# Re-dimension
trainX = train_images.reshape((nombre_train, M, N, channel))
testX = test_images.reshape((nombre_test, M, N, channel))

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(M,N,channel)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 64)                692288
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 712330 (2.72 MB)
# Trainable params: 712330 (2.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.8)
model.compile(optimizer=opt, loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
print("[INFO] training model...")
history = model.fit(trainX, train_labels, validation_data=(testX, test_labels), batch_size=64, epochs=30)
# Out:
# [INFO] training model...
# Epoch 1/30
# C:\Users\Phuoc Le\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:5729: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 782/782 [==============================] - 49s 61ms/step - loss: 1.9432 - accuracy: 0.2813 - val_loss: 1.5813 - val_accuracy: 0.4308
# Epoch 2/30
# 782/782 [==============================] - 44s 56ms/step - loss: 1.5767 - accuracy: 0.4263 - val_loss: 1.4177 - val_accuracy: 0.4960
# Epoch 3/30
# 782/782 [==============================] - 40s 51ms/step - loss: 1.4349 - accuracy: 0.4853 - val_loss: 1.3151 - val_accuracy: 0.5334
# Epoch 4/30
# 782/782 [==============================] - 42s 53ms/step - loss: 1.3262 - accuracy: 0.5259 - val_loss: 1.2532 - val_accuracy: 0.5589
# Epoch 5/30
# 782/782 [==============================] - 41s 52ms/step - loss: 1.2362 - accuracy: 0.5594 - val_loss: 1.2141 - val_accuracy: 0.5658
# Epoch 6/30
# 782/782 [==============================] - 43s 55ms/step - loss: 1.1611 - accuracy: 0.5890 - val_loss: 1.0923 - val_accuracy: 0.6180
# Epoch 7/30
# 782/782 [==============================] - 41s 52ms/step - loss: 1.0972 - accuracy: 0.6139 - val_loss: 1.0181 - val_accuracy: 0.6387
# Epoch 8/30
# 782/782 [==============================] - 37s 47ms/step - loss: 1.0418 - accuracy: 0.6321 - val_loss: 0.9864 - val_accuracy: 0.6528
# Epoch 9/30
# 782/782 [==============================] - 42s 54ms/step - loss: 0.9944 - accuracy: 0.6482 - val_loss: 0.9751 - val_accuracy: 0.6590
# Epoch 10/30
# 782/782 [==============================] - 39s 50ms/step - loss: 0.9503 - accuracy: 0.6658 - val_loss: 0.9895 - val_accuracy: 0.6497
# Epoch 11/30
# 782/782 [==============================] - 44s 56ms/step - loss: 0.9063 - accuracy: 0.6773 - val_loss: 0.9424 - val_accuracy: 0.6702
# Epoch 12/30
# 782/782 [==============================] - 45s 58ms/step - loss: 0.8690 - accuracy: 0.6923 - val_loss: 0.9127 - val_accuracy: 0.6796
# Epoch 13/30
# 782/782 [==============================] - 43s 55ms/step - loss: 0.8212 - accuracy: 0.7065 - val_loss: 0.9305 - val_accuracy: 0.6785
# Epoch 14/30
# 782/782 [==============================] - 44s 57ms/step - loss: 0.7958 - accuracy: 0.7166 - val_loss: 0.9152 - val_accuracy: 0.6886
# Epoch 15/30
# 782/782 [==============================] - 47s 60ms/step - loss: 0.7555 - accuracy: 0.7282 - val_loss: 0.9458 - val_accuracy: 0.6792
# Epoch 16/30
# 782/782 [==============================] - 44s 56ms/step - loss: 0.7199 - accuracy: 0.7383 - val_loss: 0.9280 - val_accuracy: 0.6874
# Epoch 17/30
# 782/782 [==============================] - 43s 55ms/step - loss: 0.6886 - accuracy: 0.7504 - val_loss: 0.9383 - val_accuracy: 0.6916
# Epoch 18/30
# 782/782 [==============================] - 46s 59ms/step - loss: 0.6595 - accuracy: 0.7581 - val_loss: 0.9245 - val_accuracy: 0.6936
# Epoch 19/30
# 782/782 [==============================] - 45s 58ms/step - loss: 0.6263 - accuracy: 0.7718 - val_loss: 0.9938 - val_accuracy: 0.6782
# Epoch 20/30
# 782/782 [==============================] - 43s 55ms/step - loss: 0.6021 - accuracy: 0.7767 - val_loss: 0.9655 - val_accuracy: 0.6927
# Epoch 21/30
# 782/782 [==============================] - 37s 48ms/step - loss: 0.5753 - accuracy: 0.7864 - val_loss: 0.9728 - val_accuracy: 0.6972
# Epoch 22/30
# 782/782 [==============================] - 39s 50ms/step - loss: 0.5536 - accuracy: 0.7940 - val_loss: 0.9744 - val_accuracy: 0.6941
# Epoch 23/30
# 782/782 [==============================] - 38s 48ms/step - loss: 0.5316 - accuracy: 0.8038 - val_loss: 1.0271 - val_accuracy: 0.6876
# Epoch 24/30
# 782/782 [==============================] - 35s 45ms/step - loss: 0.5101 - accuracy: 0.8095 - val_loss: 0.9931 - val_accuracy: 0.6923
# Epoch 25/30
# 782/782 [==============================] - 41s 53ms/step - loss: 0.4909 - accuracy: 0.8147 - val_loss: 1.0536 - val_accuracy: 0.6904
# Epoch 26/30
# 782/782 [==============================] - 39s 50ms/step - loss: 0.4741 - accuracy: 0.8208 - val_loss: 1.0954 - val_accuracy: 0.6886
# Epoch 27/30
# 782/782 [==============================] - 40s 51ms/step - loss: 0.4528 - accuracy: 0.8277 - val_loss: 1.0873 - val_accuracy: 0.6922
# Epoch 28/30
# 782/782 [==============================] - 38s 49ms/step - loss: 0.4372 - accuracy: 0.8338 - val_loss: 1.1187 - val_accuracy: 0.6855
# Epoch 29/30
# 782/782 [==============================] - 39s 50ms/step - loss: 0.4239 - accuracy: 0.8382 - val_loss: 1.1429 - val_accuracy: 0.6913
# Epoch 30/30
# 782/782 [==============================] - 41s 52ms/step - loss: 0.4066 - accuracy: 0.8440 - val_loss: 1.1909 - val_accuracy: 0.6857

# %%
# Create a figure with two subplots arranged vertically
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

# Plot loss on the first subplot
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_title('Model Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend(loc='upper right')

# Plot accuracy on the second subplot
ax2.plot(history.history['accuracy'], label='Training Accuracy')
ax2.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax2.set_title('Model Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend(loc='lower right')

# Improve layout and display the plot
plt.tight_layout()
plt.show()

# %%
test_loss, test_acc = model.evaluate(testX, test_labels, verbose=2)
# Out:
# 313/313 - 3s - loss: 1.1909 - accuracy: 0.6857 - 3s/epoch - 10ms/step
